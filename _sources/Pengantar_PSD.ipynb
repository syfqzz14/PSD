# %% [markdown]
# # 📘Pengantar Proyek Data Science
# 1. Konsep & Manfaat Data Science
#
# Definisi: Proses menggunakan data, matematika, statistika, dan machine learning untuk menjawab pertanyaan bisnis.
#
# Manfaat utama:
#
# Membantu keputusan bisnis berbasis data.
#
# Memahami tren pasar & perilaku pelanggan.
#
# Meningkatkan kualitas produk dan layanan.
#
# Memperbaiki proses bisnis dengan process mining.
#
# 2. Capaian Pembelajaran
#
# Menjelaskan tahapan/siklus proyek data science.
#
# Menerapkan statistika dasar → deteksi kejanggalan data.
#
# Visualisasi data → analisis & pembersihan lebih mudah.
#
# Membangun model machine learning (klasifikasi, regresi, clustering).
#
# Mengevaluasi model dengan metrik internasional (Akurasi, Recall, Precision, ROC, MSE, dll).
#
# Deploy hasil proyek ke aplikasi nyata.
#
# 3. Tahapan CRISP-DM (Standar Industri)
#
# Business Understanding
#
# Menentukan tujuan bisnis.
#
# Menyusun rencana proyek.
#
# Data Understanding
#
# Mengumpulkan & mendeskripsikan data.
#
# Eksplorasi data (EDA).
#
# Verifikasi kualitas data.
#
# Data Preprocessing
#
# Integrasi & seleksi data.
#
# Cleaning, imputasi missing value.
#
# Normalisasi & rekayasa data.
#
# Modelling
#
# Pilih metode: statistik, machine learning.
#
# Latih model → optimasi parameter.
#
# Evaluation
#
# Klasifikasi → Akurasi, Recall, Precision, ROC.
#
# Clustering → Silhouette Coefficient.
#
# Forecasting → MSE, RMSE, MAPE.
#
# Deployment
#
# Mengubah model → solusi aktif (web/app).
#
# Integrasi ke sistem bisnis (CRM, ERP).
#
# Monitoring performa model.
#
# 4. Peran & Karier Data Science
#
# Business Manager: menjembatani kebutuhan bisnis ↔ data.
#
# IT Manager: sediakan infrastruktur data.
#
# Data Science Manager: supervisi tim & tahapan proyek.
#
# Data Scientist: bangun model ML, prediksi, clustering.
#
# Data Analyst: analisis, visualisasi, insight.
#
# Data Engineer: pipeline, arsitektur data warehouse.
#
# Data Storyteller: narasi + visualisasi → decision maker.
#
# 5. Skill Utama Data Scientist
#
# Machine Learning → klasifikasi, regresi, clustering.
#
# Modelling → memilih algoritma yang tepat.
#
# Statistics → inferensial & deskriptif.
#
# Programming → Python, R.
#
# Database → SQL, NoSQL.
#
# Visualisasi → Power BI, matplotlib, seaborn.
#
# Communication → storytelling data, presentasi.
#
# 6. Tools yang Digunakan
#
# Exploratory Data Analysis (EDA) → Power BI, Exploratory, Orange.
#
# Programming → Python (Jupyter Notebook/Colab).
#
# Reporting → Jupyter Book.
#
# 7. Contoh Use Case
#
# Credit Risk Modelling → menentukan siapa yang layak kredit.
#
# Prediksi Pasar → tren harga, demand transportasi.
#
# Prediksi Kebakaran Hutan → pakai indikator cuaca & kelembaban.
#
# Process Mining → analisis bottleneck bisnis.
#
# 8. Ringkasan
#
# Data Science adalah kolaborasi bisnis + teknik + data.
#
# Siklus CRISP-DM jadi acuan proyek data.
#
# Skill utama: ML, statistik, coding, storytelling.
#
# Dampaknya: keputusan bisnis lebih cepat, tepat, dan berbasis data.
